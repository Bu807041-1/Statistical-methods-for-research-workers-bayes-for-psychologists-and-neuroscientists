# %% [markdown]
# # Opens Stats lab Tworek and Cimpian 2016 Study 1 simple (1 covariate) linear regression analyis.
# # The data can be downloaded from  https://drive.google.com/file/d/0Bz-rhZ21ShvOTl9wdHBQdG1YSDQ/view or by cloning the repositories of this notebook.

# %% [markdown]
# # STUDY DESCRIPTION
#
#
#  The ability to reason about cause and effect is a fundamental human trait. Yet, people rarely think about all of the possible causes for a particular effect, and instead rely on heuristic explanations that seemplausible. Such biases may be present for how individuals explain the status quo. When people thinkabout why something “is,” they may assume that there is an inherent property of the thing that causes itto be so. For example, imagine Susan is thinking about why she is best friends with Allison. Susan may believe that she and Allison are “meant” to be friends because they have inherent traits (e.g., similarsenses of humor) that lead them to be compatible. Susan may believe this cause to be a plausibleexplanation for her friendship with Allison, even though another reason that they are friends is that they were randomly assigned to be suitemates during their freshman year at college.People’s tendency to confuse what ‘is’ with what ‘ought to be’ is the focus of research by Tworek andCimpian (2016). These researchers wanted to determine whether individuals tendency to explain eventsbased on their inherent properties (i.e., inherence bias) would predict the extent to which they view typical outcomes as good and desirable.
#
#  To study this, the researchers recruited 122 individuals from an online participant pool. The participants first read six articles that explained a status quo societal practice (e.g., Americans eat a lot of pizza). Afterreading each article, participants responded to various questions assessing the extent to which the status quo ought to occur (e.g., Americans eat a lot of pizza because pizza is delicious). These questions measured participants tendency to make Ought inferences. Next, participants responded to 15 items designed to measure their level of inherence bias (i.e., their tendency to explain events based on inherent properties). Participants also completed various additional measures, including a measure of intelligence
#
# (Raven’s Progressive Matrix), belief in a just world, political views (Conservatism), and demographics (education). For more details, see the Tworek and Cimpian (2016) Study 1 method section.

# %%
# Import relevant packages for analysis below.

# %matplotlib inline
import pystan as ps
import numpy as np
import pandas as pd
import seaborn
import arviz as az
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
#Change working driectory
os.chdir(r"C:\Users\harri\OneDrive\Documents\Repositories\Statistical-methods-for-research-workers-bayes-for-psychologists-and-neuroscientists\Data")

# Import Data into pandas dataframe 
df = pd.read_csv("Tworek and Cimpian 2016 Study 1.csv")

#Output dataframe (first few rows)
df.head()
# Out:
#    excluded  RavensProgressiveMatrix_sum  Inherence_Bias  Should_Score  \
# 0         0                            5        7.666667      6.333333
# 1         1                            5        7.333333      6.666667
# 2         0                            4        5.333333      5.666667
# 3         0                            2        5.800000      8.000000
# 4         0                            2        4.266667      7.000000
#
#    Good_Score  Ought_Score  Belief_in_Just_World  \
# 0    6.666667     6.500000                  5.65
# 1    8.000000     7.333333                  4.60
# 2    2.666667     4.166667                  4.20
# 3    7.666667     7.833333                  4.85
# 4    3.666667     5.333333                  4.65
#
#    instructionsâ onthefollowingscreensyouwillbeaskedtofilloutseve  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# ...

# %%
# The paper identified american participants coded 0 in filter_$ coloumn
# and are removed below by extracting all values in that column eqaul to 1
# into new dataframe.

filtered = df[df["filter_$"] == 1]

# Assign the Ought group to a variable and coneverting values into numpy array.
Ought = filtered["Ought_Score"].to_numpy()

# Assign the Inheriance group to a varaible and coneverting values into numpy array.
Inherence_Bias = filtered["Inherence_Bias"].to_numpy()

# %%
#Check for NA/missing data for Ought scores
filtered["Ought_Score"].isnull()
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 126    False
# 127    False
# 128    False
# 129    False
# 130    False
# Name: Ought_Score, Length: 122, dtype: bool

# %%
#Check for NA/missing data for Ought scores
filtered["Inherence_Bias"].isnull()
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 126    False
# 127    False
# 128    False
# 129    False
# 130    False
# Name: Inherence_Bias, Length: 122, dtype: bool

# %% [markdown]
# # Regression model specified below
#
# # $$y \sim \alpha + \beta_{1}x$$
# # $$ \sigma \sim Normal(0, 10) $$ $$ \alpha \sim Normal(0, 10) $$ $$ \beta_{1} \sim Cauchy(0, 2.5) $$

# %%
# Stan regression model coded into a string to be called for C++ compilation and HMC 
# sampling of the posterior distribution below.

Simple_Regression_model= """ 
data {

  int<lower=0> N; //interger lower bound of 0
  vector[N] x; // specifying vector length of Precitor varaible (IV).
  vector[N] y; // specifying vector length of predcited variable (DV).
  
}

parameters {

  // Specify simple regression model parameters specified.
  
  real alpha; // intercepy
  real beta; //slope coefficent
  real<lower=0> sigma; // Standard deviation
  
}

model {

  // priors
  alpha ~ normal(0, 0);
  beta ~ normal(0, 10);
  sigma ~ cauchy(0, 2.5); 
  
  y ~ normal(alpha + beta * x, sigma);
  
}

"""

# %%
# Python dictionary of data values for calling to Stan and for model fitting
data = {"N": len(Ought),
                   "y": Ought,
                   "x": Inherence_Bias}

# %%
#Compile stan model to C++ code to sample posterior for the model below
sm  = ps.StanModel(model_code = Simple_Regression_model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_4595a8ab98547c3961c6cdd53d49cac0 NOW.

# %%
# Fit and sample model
fit = sm.sampling(data = data, iter = 10000, chains=4, seed= 302675)

# %%
print(fit)
# Out:
# Inference for Stan model: anon_model_4595a8ab98547c3961c6cdd53d49cac0.
# 4 chains, each with iter=10000; warmup=5000; thin=1;
# post-warmup draws per chain=5000, total post-warmup draws=20000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# alpha   3.09  6.2e-3   0.48   2.14   2.77   3.09   3.41   4.01   5820    1.0
# beta    0.43  1.0e-3   0.08   0.28   0.38   0.43   0.48   0.59   5843    1.0
# sigma   1.09  8.0e-4   0.07   0.96   1.04   1.09   1.14   1.25   8222    1.0
# lp__  -76.12    0.02   1.26 -79.42 -76.69 -75.79  -75.2  -74.7   6415    1.0
#
# Samples were drawn using NUTS at Tue Dec 15 19:26:16 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %% [markdown]
# # Plotting posterior distributions for the fitted model parameters

# %%
# Posterior plots showing the defaults 94% Credible interval of the arviz package
az.plot_posterior(fit)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002710E7B3788>,
# ...
#       dtype=object)

# %% [markdown]
# # Trace plot belows showing good chain mixing with the chains showing fuzzy cateplilars and not slithering snakes.

# %%
# Trace plots
az.plot_trace(fit);

# %% [markdown]
# # Regreesion analysis plots

# %%
#First take a random sample of the posterior parameter estimates for plotting
posterior_samples = pd.DataFrame(fit.extract())
posterior_samples_red = pd.DataFrame()

#for loop over and sample posterior parmaters in pandas data frame into new dataframe
for index in np.arange(posterior_samples.shape[1]):
    subset = posterior_samples.iloc[: , index]
    subset = np.random.choice(subset, size = 2000, replace = False)
    posterior_samples_red[index] = subset

# %%
for row in range(0, len(posterior_samples_red)):
 fit_line = np.poly1d([posterior_samples_red[1][row], posterior_samples_red[0][row]])
 x = np.arange(11)
 y = fit_line(x)
 plt.plot(x, y, "b-", alpha = 0.025, zorder=1)
 plt.scatter(Inherence_Bias, Ought, c = "r", s=1, zorder=2)
 plt.title("All Stan Fits Together")
 plt.ylim(0,10)
 plt.ylabel("Ought")
 plt.xlabel("Inherence_Bias")
#
x_vals = np.arange(11)
y_vals = np.mean(fit["alpha"]) + np.mean(fit["beta"]) * x_vals
plt.plot(x_vals, y_vals, 'r-')
plt.scatter(Inherence_Bias,Ought, s=2)
plt.ylabel("Ought")
plt.xlabel("Inherence_Bias")
# Out:
# Text(0.5, 0, 'Inherence_Bias')

# %% [markdown]
# # MAP estimate for the fitted regression model

# %%
x_vals = np.arange(11)
y_vals = np.mean(fit["alpha"]) +np.mean(fit["beta"]) * x_vals
plt.plot(x_vals, y_vals, '-')
plt.scatter(Inherence_Bias,Ought, s=2)
plt.ylabel("Ought")
plt.xlabel("Inherence_Bias")
# Out:
# Text(0.5, 0, 'Inherence_Bias')

# %%
pd.DataFrame(fit.extract(pars = ["beta", "alpha"]))
# Out:
#            beta     alpha
# 0      0.420015  3.167361
# 1      0.408720  3.248558
# 2      0.472016  3.029283
# 3      0.418193  3.148489
# 4      0.417814  3.260358
# ...         ...       ...
# 19995  0.346567  3.737779
# 19996  0.421869  3.224329
# 19997  0.491332  2.801782
# 19998  0.336178  3.651629
# 19999  0.452748  3.056722
#
# [20000 rows x 2 columns]
