# %% [markdown]
# # Bayesian Between subjects t-test.
#
# # Statistical test for comparing the means of two groups with continous data.

# %%
# Import the neccesary python libraries for Bayesian analysis
# and data visualisation.

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import pandas as pd
import os
import pystan as ps
import arviz as az

# %% [markdown]
# ### The  data can be dowloaded from the OSF framework,"Data_Final.csv", from https://osf.io/uszvx/ - or by cloning the repository from Github

# %%
#Use os to change working directory to import data into jupyter notebook for analysis
os.chdir("C:\\Users\\harri/OneDrive/Documents/Repositories/Statistical-methods-for-research-workers-bayes-for-psychologists-and-neuroscientists/Data/")

#Read in csv file to dataframe
df = pd.read_csv("Turning_Hands_Data_Final.csv")

#Extrract neo mean (openess to experience) scores and Rotation conditions for comparison below
df_Mu_neo_condt = df[["mean_NEO", "Rotation"]]
df_Mu_neo_condt.head()
# Out:
#    mean_NEO Rotation
# 0  0.666667  counter
# 1  1.166667    clock
# 2  0.833333  counter
# 3  0.000000    clock
# 4 -0.250000  counter

# %%
#Extract counter clockwise groups neo-score means and convert into numpy array for vectorisation using python dictionary below.
df_counter = df_Mu_neo_condt[df_Mu_neo_condt['Rotation'].str.contains('co')]

counter = df_counter["mean_NEO"].to_numpy()

# Extract counter clockwie groups neo means and convert into numpy array for vectorisation using python dictionary below.
df_clock = df_Mu_neo_condt[df_Mu_neo_condt['Rotation'].str.contains('cl')]

clock = df_clock["mean_NEO"].to_numpy()

# %% [markdown]
# # Plotting histograms of the two groups data or expolratory check

# %%
sns.distplot(counter,hist=True,kde=False)

# %%
sns.distplot(clock, hist=True,kde=False)

# %% [markdown]
# ## Between subject Mean estimation in Stan. simplest model estimating just the Means and difference of two independent groups, with uniform priors bounded by the neo scale scores -2,+2. default prior on the $\sigma$ parameter.
# ### $$y_{1} \sim {\sf N(\mu,\sigma)}$$ $$y_{2} \sim {\sf N(\mu,\sigma)}$$$$\mu_{1,2}\sim U(-2,+2)$$$$\sigma_{1,2}\sim U(-\infty,+\infty) $$

# %%
#Stan model put into string to be called when the model is compiled
Independent_t = """

data {
  int<lower=0> N1;  // # of observations (counter clockwise)
  int<lower=0> N2;  // # of observations (clockwise)
  vector[N1] Y1;  // Neo scores (counter clockwise)
  vector[N2] Y2;  // Neo scores (clockwise);
}

parameters {
  real<lower=-2,upper=2> mu_1;  // mean of (counter clockwise) group bounded to lower -2 and upper 2 in line with the likert
  //scale on the neo personality measure.
  real<lower=-2,upper=2> mu_2;  // mean of (clockwise) group 
  real<lower=0> sigma; // pooled standard deviation
}

model {

// likelihood
  Y1 ~ normal(mu_1, sigma);
  Y2 ~ normal(mu_2, sigma);
}

generated quantities {
  real cohen_d = (mu_2 - mu_1);// / sigma; //effect size;
}

"""
#Cohen D being generated form the posterior samples

# %%
#Create python dictionary to specify the data to be modelled using th stan coded model above,
#(Should provalbly use length funtion for the N vector.
Model_t_dat = {'N1': len(counter) ,
               'N2': len(clock),             
               'Y1': counter,
               'Y2': clock}

# %%
#Fit the model using 2000 sample iterations and 4 chains with the 4 cores on this machine.
#If you have more you can use more if less then use less.

sm = ps.StanModel(model_code = Independent_t)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_35f1fbb6789109324c5876037799ebc7 NOW.

# %% [markdown]
# # Fit Stan model

# %%
fit = sm.sampling(data= Model_t_dat, iter=10000, chains=4, seed= 302675)

# %% [markdown]
# # Print model output

# %%
#Print the outputs STAN model for comparison of independent means. 
print(fit)

# EXtract samples generated from the posterior
samples = fit.extract()
# Out:
# Inference for Stan model: anon_model_35f1fbb6789109324c5876037799ebc7.
# 4 chains, each with iter=10000; warmup=5000; thin=1;
# post-warmup draws per chain=5000, total post-warmup draws=20000.
#
#           mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu_1      0.71  5.0e-4   0.07   0.58   0.67   0.71   0.76   0.84  17756    1.0
# mu_2      0.64  5.4e-4   0.07    0.5   0.59   0.64   0.69   0.78  17313    1.0
# sigma     0.49  2.8e-4   0.04   0.43   0.47   0.49   0.51   0.57  16661    1.0
# cohen_d  -0.07  7.2e-4    0.1  -0.26  -0.14  -0.07-7.7e-3   0.12  18023    1.0
# lp__     21.54    0.01   1.26  18.29  20.97  21.86  22.46  22.96   9917    1.0
#
# Samples were drawn using NUTS at Wed Nov 18 21:16:26 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %% [markdown]
# # Plot posteriors and Traceplots from the MCMC sampling of the Stan model.

# %%
az.plot_posterior(fit)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021279F31A08>,
# ...
#       dtype=object)

# %%
az.plot_trace(fit)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002127C940508>,
# ...
#       dtype=object)

# %% [markdown]
# ### The posterior plots from the arviz package show the 94% credible interval of the estimated posterior disitributions
#
# ### for the means, pooled standard deviations(estimated on only for the cohen d calcuation). The cohen d standardised mean difference
#
#
# ### Kruskche (2013) as while the point estimate suggests a diffenece, the credible interval spans across zero
# ### so the diffence could reasonalbe be credible in either direction.

# %% [markdown]
# # ============

# %% [markdown]
# # Within pycholgoical research the standardly applied statictical tests (t-test, ANOVA, Regression) are all a variant application of the General linear model (GLM, see Rutherford, 2011). As such the model above can be recoded to express the results as a categorical regression within the Bayesian Framework.

# %% [markdown]
# # Two group categorical Regression.

# %%
Two_group_categorical_Regression = """
data{
int N;
vector[N] y;
vector[N] x;

}

parameters{
real<lower=-2,upper =2> alpha;
real beta;
real<lower=0> sigma;
}

model{
// Priors 
alpha ~ normal(0,1);
beta ~ normal(0,1);
sigma ~ normal(0, 10);
//Likelihood
y ~ normal(alpha + x * beta, sigma); // Estimation all through one likelihood function

}

"""

# %%
sm_2 = ps.StanModel(model_code = Two_group_categorical_Regression)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_4d1ec45e7f8ca5ad8aff3c29b11001e6 NOW.

# %%
from patsy import dmatrix, dmatrices

# %%
#Using the patsy library allows for easy design matrix generation and then manipualtion for use in Stan
DM = dmatrix("mean_NEO + Rotation ", df_Mu_neo_condt)

DM = pd.DataFrame(DM, columns=DM.design_info.column_names)
T_DM = DM['Rotation[T.counter]'].astype(int).values
Eff_DM = (T_DM-0.5)
Eff_DM
# Out:
# array([ 0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5,
#        -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5,  0.5,
#        -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,
#         0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5, -0.5,
#         0.5, -0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,
#         0.5, -0.5,  0.5, -0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,
#         0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5,
#         0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5, -0.5,  0.5,
#         0.5, -0.5,  0.5,  0.5, -0.5,  0.5,  0.5, -0.5,  0.5,  0.5, -0.5,
#         0.5,  0.5,  0.5])

# %%
Two_group__Treat_categorical_Regression_dat = {'N': len(df_Mu_neo_condt),
                                       'y': df_Mu_neo_condt["mean_NEO"].values,
                                       'x': T_DM}

Two_group__Eff_categorical_Regression_dat = {'N': len(df_Mu_neo_condt),
                                       'y': df_Mu_neo_condt["mean_NEO"].values,
                                       'x': Eff_DM}

# %%
fit_T = sm_2.sampling(data = Two_group__Treat_categorical_Regression_dat, iter = 2000, chains=4, seed= 302675)
fit_Eff = sm_2.sampling(data = Two_group__Eff_categorical_Regression_dat, iter = 2000, chains=4, seed= 302675)

# %%
print(fit_T)
# Out:
# Inference for Stan model: anon_model_4d1ec45e7f8ca5ad8aff3c29b11001e6.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# alpha   0.64  1.5e-3   0.07    0.5   0.59   0.64   0.68   0.78   2181    1.0
# beta    0.08  2.1e-3    0.1  -0.11   0.01   0.08   0.14   0.27   2219    1.0
# sigma   0.49  6.8e-4   0.03   0.43   0.47   0.49   0.51   0.57   2661    1.0
# lp__   21.48    0.03   1.24  18.33  20.89  21.81  22.39  22.89   1570    1.0
#
# Samples were drawn using NUTS at Wed Nov 18 22:09:13 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
az.plot_posterior(fit_T)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021201D2FFC8>,
# ...
#       dtype=object)

# %%
az.plot_trace(fit_T)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021200E63848>,
# ...
#       dtype=object)

# %%
print(fit_Eff)
# Out:
# Inference for Stan model: anon_model_4d1ec45e7f8ca5ad8aff3c29b11001e6.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# alpha   0.68  7.7e-4   0.05   0.58   0.64   0.68   0.71   0.77   3961    1.0
# beta    0.07  1.6e-3    0.1  -0.12 5.9e-3   0.07   0.14   0.26   3816    1.0
# sigma   0.49  5.5e-4   0.04   0.43   0.46   0.49   0.51   0.57   4067    1.0
# lp__   21.44    0.03   1.21  18.32  20.87  21.72  22.33  22.85   2224    1.0
#
# Samples were drawn using NUTS at Wed Nov 18 22:09:16 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
summary_dict = fit_T.summary()
df_1 = pd.DataFrame(summary_dict['summary'], 
                  columns=summary_dict['summary_colnames'], 
                  index=summary_dict['summary_rownames'])
df_1
# Out:
#             mean   se_mean        sd       2.5%        25%        50%  \
# alpha   0.636826  0.001515  0.070730   0.496919   0.591661   0.637143
# beta    0.078689  0.002068  0.097416  -0.111170   0.013213   0.079536
# sigma   0.490987  0.000678  0.034972   0.428440   0.465960   0.489440
# lp__   21.478847  0.031185  1.235637  18.330810  20.889396  21.813981
#
#              75%      97.5%        n_eff      Rhat
# alpha   0.684525   0.775256  2180.830405  1.001008
# beta    0.142297   0.273924  2219.183362  1.000176
# sigma   0.513502   0.565016  2661.476981  1.001984
# lp__   22.387662  22.892703  1569.989674  1.000456

# %%
def abline(slope, intercept):
    """Plot a line from slope and intercept"""
    axes = plt.gca()
    x_vals = np.array(axes.get_xlim())
    y_vals = intercept + slope * x_vals
    plt.plot(x_vals, y_vals, '-')
    
alpha = df_1.loc['alpha','mean']
beta = df_1.loc['beta','mean']

sns.catplot(x = "Rotation", y = "mean_NEO",order= ['clock','counter'],data=df_Mu_neo_condt)
abline(alpha,beta)

# %%
s
# Out:
# 0.7129629630185185
